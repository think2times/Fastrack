# %%
path = 'datasets/bitly_usagov/example.txt'

# %%
with open(path) as f:
    print(f.readline())
# Out:
# { "a": "Mozilla\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\/535.11 (KHTML, like Gecko) Chrome\/17.0.963.78 Safari\/535.11", "c": "US", "nk": 1, "tz": "America\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\/\/www.facebook.com\/l\/7AQEFzjSi\/1.usa.gov\/wfLQtf", "u": "http:\/\/www.ncbi.nlm.nih.gov\/pubmed\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }

# %%
import json

with open(path) as f:
    records = [json.loads(line) for line in f]

# %%
records[0]
# Out:
# {'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  'c': 'US',
#  'nk': 1,
#  'tz': 'America/New_York',
#  'gr': 'MA',
#  'g': 'A6qOVH',
#  'h': 'wfLQtf',
#  'l': 'orofrog',
#  'al': 'en-US,en;q=0.8',
#  'hh': '1.usa.gov',
#  'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991',
#  't': 1331923247,
#  'hc': 1331822918,
#  'cy': 'Danvers',
#  'll': [42.576698, -70.954903]}

# %%
records[1]
# Out:
# {'a': 'GoogleMaps/RochesterNY',
#  'c': 'US',
#  'nk': 0,
#  'tz': 'America/Denver',
#  'gr': 'UT',
#  'g': 'mwszkS',
#  'h': 'mwszkS',
#  'l': 'bitly',
#  'hh': 'j.mp',
#  'r': 'http://www.AwareMap.com/',
#  'u': 'http://www.monroecounty.gov/etc/911/rss.php',
#  't': 1331923249,
#  'hc': 1308262393,
#  'cy': 'Provo',
#  'll': [40.218102, -111.613297]}

# %%
time_zones = [rec['tz'] for rec in records if 'tz' in rec]
time_zones[:10]
# Out:
# ['America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/Sao_Paulo',
#  'America/New_York',
#  'America/New_York',
#  'Europe/Warsaw',
#  '',
#  '',
#  '']

# %%
def get_counts(sequence):
    counts = {}
    for x in sequence:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1
    return counts

# %%
counts = get_counts(time_zones)
counts['America/New_York']
# Out:
# 1251

# %%
len(time_zones)
# Out:
# 3440

# %%
def top_counts(count_dict, n=10):
    value_key_pairs = [(count, tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]

# %%
top_counts(counts)
# Out:
# [(33, 'America/Sao_Paulo'),
#  (35, 'Europe/Madrid'),
#  (36, 'Pacific/Honolulu'),
#  (37, 'Asia/Tokyo'),
#  (74, 'Europe/London'),
#  (191, 'America/Denver'),
#  (382, 'America/Los_Angeles'),
#  (400, 'America/Chicago'),
#  (521, ''),
#  (1251, 'America/New_York')]

# %%
from collections import Counter

counts = Counter(time_zones)
counts.most_common(10)
# Out:
# [('America/New_York', 1251),
#  ('', 521),
#  ('America/Chicago', 400),
#  ('America/Los_Angeles', 382),
#  ('America/Denver', 191),
#  ('Europe/London', 74),
#  ('Asia/Tokyo', 37),
#  ('Pacific/Honolulu', 36),
#  ('Europe/Madrid', 35),
#  ('America/Sao_Paulo', 33)]

# %%
import pandas as pd

frame = pd.DataFrame(records)
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3560 entries, 0 to 3559
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   a            3440 non-null   object
#  1   c            2919 non-null   object
#  2   nk           3440 non-null   float64
#  3   tz           3440 non-null   object
#  4   gr           2919 non-null   object
#  5   g            3440 non-null   object
#  6   h            3440 non-null   object
#  7   l            3440 non-null   object
#  8   al           3094 non-null   object
#  9   hh           3440 non-null   object
#  10  r            3440 non-null   object
#  11  u            3440 non-null   object
#  12  t            3440 non-null   float64
#  13  hc           3440 non-null   float64
#  14  cy           2919 non-null   object
#  15  ll           2919 non-null   object
#  16  _heartbeat_  120 non-null    float64
#  17  kw           93 non-null     object
# dtypes: float64(4), object(14)
# memory usage: 500.8+ KB

# %%
frame['tz'].head()
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# Name: tz, dtype: object

# %%
tz_counts = frame['tz'].value_counts()
tz_counts.head()
# Out:
# tz
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Name: count, dtype: int64

# %%
tz_counts[:10]
# Out:
# tz
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: count, dtype: int64

# %%
clean_tz = frame['tz'].fillna('Missing')
clean_tz[clean_tz == ''] = 'Unknown'
tz_counts = clean_tz.value_counts()
tz_counts.head()
# Out:
# tz
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Name: count, dtype: int64

# %%
import seaborn as sns

subset = tz_counts.head()
sns.barplot(y=subset.index, x=subset.to_numpy())
# Out:
# <Axes: ylabel='tz'>

# %%
frame['a'][1]
# Out:
# 'GoogleMaps/RochesterNY'

# %%
frame['a'][5]
# Out:
# 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11'

# %%
frame['a'][51][:50]
# Out:
# 'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P9'

# %%
results = pd.Series([x.split()[0] for x in frame['a'].dropna()])
results.head()
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts().head(8)
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# Name: count, dtype: int64

# %%
import numpy as np

cframe = frame[frame['a'].notna()].copy()
cframe['os'] = np.where(cframe['a'].str.contains('Windows'), 'Windows', 'Not Windows')
cframe['os'].head()
# Out:
# 0        Windows
# 1    Not Windows
# 2        Windows
# 3    Not Windows
# 4        Windows
# Name: os, dtype: object

# %%
by_tz_os = cframe.groupby(['tz', 'os'])

for (k1, k2), value in by_tz_os['t']:
    print((k1, k2))
    print(value.mean())
# Out:
# ('', 'Not Windows')
# 1331924863.297959
# ('', 'Windows')
# 1331924876.0507247
# ('Africa/Cairo', 'Windows')
# 1331923896.0
# ('Africa/Casablanca', 'Windows')
# 1331926299.0
# ('Africa/Ceuta', 'Windows')
# 1331924695.5
# ('Africa/Johannesburg', 'Windows')
# 1331925332.0
# ('Africa/Lusaka', 'Windows')
# 1331924925.0
# ('America/Anchorage', 'Not Windows')
# 1331925117.75
# ('America/Anchorage', 'Windows')
# 1331923335.0
# ('America/Argentina/Buenos_Aires', 'Not Windows')
# 1331924105.0
# ('America/Argentina/Cordoba', 'Windows')
# 1331925543.0
# ('America/Argentina/Mendoza', 'Windows')
# 1331924531.0
# ('America/Bogota', 'Not Windows')
# 1331924648.0
# ('America/Bogota', 'Windows')
# 1331923603.5
# ('America/Caracas', 'Windows')
# 1331924514.0
# ('America/Chicago', 'Not Windows')
# 1331925052.278261
# ('America/Chicago', 'Windows')
# 1331925209.4736843
# ('America/Chihuahua', 'Not Windows')
# 1331926283.0
# ('America/Chihuahua', 'Windows')
# 1331924883.0
# ('America/Costa_Rica', 'Windows')
# 1331924669.0
# ('America/Denver', 'Not Windows')
# 1331925031.371212
# ('America/Denver', 'Windows')
# 1331925118.9152544
# ('America/Edmonton', 'Not Windows')
# 1331925726.5
# ('America/Edmonton', 'Windows')
# 1331924887.0
# ('America/Guayaquil', 'Not Windows')
# 1331925064.5
# ('America/Halifax', 'Not Windows')
# 1331924636.0
# ('America/Halifax', 'Windows')
# 1331924527.0
# ('America/Indianapolis', 'Not Windows')
# 1331925452.0
# ('America/Indianapolis', 'Windows')
# 1331925002.8333333
# ('America/La_Paz', 'Windows')
# 1331926274.0
# ('America/Lima', 'Windows')
# 1331924704.0
# ('America/Los_Angeles', 'Not Windows')
# 1331924885.4230769
# ('America/Los_Angeles', 'Windows')
# 1331924780.5317461
# ('America/Managua', 'Windows')
# 1331924937.6666667
# ('America/Mazatlan', 'Not Windows')
# 1331923313.0
# ('America/Mexico_City', 'Not Windows')
# 1331924502.0
# ('America/Mexico_City', 'Windows')
# 1331924587.25
# ('America/Monterrey', 'Not Windows')
# 1331923933.0
# ('America/Montevideo', 'Windows')
# 1331924516.0
# ('America/Montreal', 'Not Windows')
# 1331925322.3333333
# ('America/Montreal', 'Windows')
# 1331924614.3333333
# ('America/New_York', 'Not Windows')
# 1331924935.4041297
# ('America/New_York', 'Windows')
# 1331924951.0372808
# ('America/Phoenix', 'Not Windows')
# 1331925799.0
# ('America/Phoenix', 'Windows')
# 1331925062.5294118
# ('America/Puerto_Rico', 'Not Windows')
# 1331924963.6666667
# ('America/Puerto_Rico', 'Windows')
# 1331924151.0
# ('America/Rainy_River', 'Not Windows')
# 1331924589.9
# ('America/Rainy_River', 'Windows')
# 1331924875.0
# ('America/Recife', 'Windows')
# 1331924176.5
# ('America/Santo_Domingo', 'Not Windows')
# 1331925469.0
# ('America/Sao_Paulo', 'Not Windows')
# 1331924228.6923077
# ('America/Sao_Paulo', 'Windows')
# 1331924867.25
# ('America/St_Kitts', 'Not Windows')
# 1331925358.0
# ('America/Tegucigalpa', 'Windows')
# 1331926825.0
# ('America/Vancouver', 'Not Windows')
# 1331924192.0
# ('America/Vancouver', 'Windows')
# 1331924560.6666667
# ('America/Winnipeg', 'Not Windows')
# 1331924826.3333333
# ('America/Winnipeg', 'Windows')
# 1331925313.0
# ('Asia/Amman', 'Windows')
# 1331925234.5
# ('Asia/Bangkok', 'Windows')
# 1331923983.5
# ('Asia/Beirut', 'Not Windows')
# 1331924671.0
# ('Asia/Beirut', 'Windows')
# 1331924296.3333333
# ('Asia/Calcutta', 'Not Windows')
# 1331925509.0
# ('Asia/Calcutta', 'Windows')
# 1331924832.0
# ('Asia/Dubai', 'Not Windows')
# 1331926554.5
# ('Asia/Dubai', 'Windows')
# 1331925117.5
# ('Asia/Harbin', 'Windows')
# 1331925498.6666667
# ('Asia/Hong_Kong', 'Not Windows')
# 1331923621.75
# ('Asia/Hong_Kong', 'Windows')
# 1331923528.3333333
# ('Asia/Istanbul', 'Windows')
# 1331924386.7777777
# ('Asia/Jakarta', 'Not Windows')
# 1331926572.5
# ('Asia/Jakarta', 'Windows')
# 1331926632.0
# ('Asia/Jerusalem', 'Not Windows')
# 1331925766.0
# ('Asia/Jerusalem', 'Windows')
# 1331923433.0
# ('Asia/Karachi', 'Windows')
# 1331924563.6666667
# ('Asia/Kuala_Lumpur', 'Not Windows')
# 1331923337.0
# ('Asia/Kuala_Lumpur', 'Windows')
# 1331924631.0
# ('Asia/Kuching', 'Windows')
# 1331925833.0
# ('Asia/Manila', 'Windows')
# 1331924272.0
# ('Asia/Nicosia', 'Windows')
# 1331923268.0
# ('Asia/Novosibirsk', 'Windows')
# 1331923677.0
# ('Asia/Pontianak', 'Not Windows')
# 1331924727.0
# ('Asia/Riyadh', 'Windows')
# 1331924513.0
# ('Asia/Seoul', 'Not Windows')
# 1331926557.75
# ('Asia/Seoul', 'Windows')
# 1331924541.0
# ('Asia/Tokyo', 'Not Windows')
# 1331924703.0
# ('Asia/Tokyo', 'Windows')
# 1331924100.8857143
# ('Asia/Yekaterinburg', 'Windows')
# 1331924241.0
# ('Australia/NSW', 'Not Windows')
# 1331925220.4
# ('Australia/NSW', 'Windows')
# 1331925060.0
# ('Australia/Queensland', 'Windows')
# 1331924570.0
# ('Chile/Continental', 'Not Windows')
# 1331924126.4
# ('Chile/Continental', 'Windows')
# 1331925458.0
# ('Europe/Amsterdam', 'Not Windows')
# 1331925809.9166667
# ('Europe/Amsterdam', 'Windows')
# 1331924842.7
# ('Europe/Athens', 'Not Windows')
# 1331924857.0
# ('Europe/Athens', 'Windows')
# 1331924191.6666667
# ('Europe/Belgrade', 'Windows')
# 1331924946.0
# ('Europe/Berlin', 'Not Windows')
# 1331924891.1111112
# ('Europe/Berlin', 'Windows')
# 1331924553.2105262
# ('Europe/Bratislava', 'Not Windows')
# 1331924254.0
# ('Europe/Bratislava', 'Windows')
# 1331924333.0
# ('Europe/Brussels', 'Not Windows')
# 1331923645.0
# ('Europe/Brussels', 'Windows')
# 1331924305.3333333
# ('Europe/Bucharest', 'Not Windows')
# 1331924034.0
# ('Europe/Bucharest', 'Windows')
# 1331925055.6666667
# ('Europe/Budapest', 'Windows')
# 1331925080.4
# ('Europe/Copenhagen', 'Not Windows')
# 1331924255.5
# ('Europe/Copenhagen', 'Windows')
# 1331924786.0
# ('Europe/Dublin', 'Not Windows')
# 1331924713.0
# ('Europe/Dublin', 'Windows')
# 1331923374.5
# ('Europe/Helsinki', 'Not Windows')
# 1331924516.0
# ('Europe/Helsinki', 'Windows')
# 1331926109.625
# ('Europe/Lisbon', 'Not Windows')
# 1331923454.0
# ('Europe/Lisbon', 'Windows')
# 1331924486.2857144
# ('Europe/Ljubljana', 'Windows')
# 1331923807.0
# ('Europe/London', 'Not Windows')
# 1331925139.0697675
# ('Europe/London', 'Windows')
# 1331924610.483871
# ('Europe/Madrid', 'Not Windows')
# 1331925027.0
# ('Europe/Madrid', 'Windows')
# 1331924763.0526316
# ('Europe/Malta', 'Windows')
# 1331924055.0
# ('Europe/Moscow', 'Not Windows')
# 1331926283.0
# ('Europe/Moscow', 'Windows')
# 1331925269.5555556
# ('Europe/Oslo', 'Not Windows')
# 1331926407.0
# ('Europe/Oslo', 'Windows')
# 1331925511.25
# ('Europe/Paris', 'Not Windows')
# 1331925306.25
# ('Europe/Paris', 'Windows')
# 1331924544.5
# ('Europe/Prague', 'Not Windows')
# 1331924619.0
# ('Europe/Prague', 'Windows')
# 1331924320.857143
# ('Europe/Riga', 'Not Windows')
# 1331926028.0
# ('Europe/Riga', 'Windows')
# 1331924015.0
# ('Europe/Rome', 'Not Windows')
# 1331925028.375
# ('Europe/Rome', 'Windows')
# 1331924214.0
# ('Europe/Skopje', 'Windows')
# 1331923455.0
# ('Europe/Sofia', 'Windows')
# 1331923758.0
# ('Europe/Stockholm', 'Not Windows')
# 1331926381.0
# ('Europe/Stockholm', 'Windows')
# 1331924960.75
# ('Europe/Uzhgorod', 'Windows')
# 1331924565.0
# ('Europe/Vienna', 'Not Windows')
# 1331924615.0
# ('Europe/Vienna', 'Windows')
# 1331923433.6666667
# ('Europe/Vilnius', 'Windows')
# 1331925044.0
# ('Europe/Volgograd', 'Windows')
# 1331926162.0
# ('Europe/Warsaw', 'Not Windows')
# 1331924673.0
# ('Europe/Warsaw', 'Windows')
# 1331924428.0666666
# ('Europe/Zurich', 'Not Windows')
# 1331924967.75
# ('Pacific/Auckland', 'Not Windows')
# 1331925860.3333333
# ('Pacific/Auckland', 'Windows')
# 1331925726.375
# ('Pacific/Honolulu', 'Windows')
# 1331924192.3611112

# %%
agg_counts = by_tz_os.size().unstack().fillna(0)
agg_counts.head()
# Out:
# os                   Not Windows  Windows
# tz
#                            245.0    276.0
# Africa/Cairo                 0.0      3.0
# Africa/Casablanca            0.0      1.0
# Africa/Ceuta                 0.0      2.0
# Africa/Johannesburg          0.0      1.0

# %%
indexer = agg_counts.sum('columns').argsort()
indexer.values[:10]
# Out:
# array([ 2,  7,  5,  4, 14, 11,  9,  8, 24, 26])

# %%
count_subset = agg_counts.take(indexer.values[-10:])
count_subset
# Out:
# os                   Not Windows  Windows
# tz
# America/Sao_Paulo           13.0     20.0
# Europe/Madrid               16.0     19.0
# Pacific/Honolulu             0.0     36.0
# Asia/Tokyo                   2.0     35.0
# Europe/London               43.0     31.0
# America/Denver             132.0     59.0
# America/Los_Angeles        130.0    252.0
# America/Chicago            115.0    285.0
#                            245.0    276.0
# America/New_York           339.0    912.0

# %%
agg_counts.sum('columns').nlargest(10)
# Out:
# tz
# America/New_York       1251.0
#                         521.0
# America/Chicago         400.0
# America/Los_Angeles     382.0
# America/Denver          191.0
# Europe/London            74.0
# Asia/Tokyo               37.0
# Pacific/Honolulu         36.0
# Europe/Madrid            35.0
# America/Sao_Paulo        33.0
# dtype: float64

# %%
count_subset = count_subset.stack()
count_subset.name = 'total'
count_subset = count_subset.reset_index()
count_subset.head(10)
# Out:
#                   tz           os  total
# 0  America/Sao_Paulo  Not Windows   13.0
# 1  America/Sao_Paulo      Windows   20.0
# 2      Europe/Madrid  Not Windows   16.0
# 3      Europe/Madrid      Windows   19.0
# 4   Pacific/Honolulu  Not Windows    0.0
# 5   Pacific/Honolulu      Windows   36.0
# 6         Asia/Tokyo  Not Windows    2.0
# 7         Asia/Tokyo      Windows   35.0
# 8      Europe/London  Not Windows   43.0
# 9      Europe/London      Windows   31.0

# %%
sns.barplot(x='total', y='tz', hue='os', data=count_subset)
# Out:
# <Axes: xlabel='total', ylabel='tz'>

# %%
def norm_total(group):
    group['normed_total'] = group['total'] / group['total'].sum()
    return group

# %%
results = count_subset.groupby('tz').apply(norm_total, include_groups=False)
results.head()
# Out:
#                              os  total  normed_total
# tz
#                 16  Not Windows  245.0      0.470250
#                 17      Windows  276.0      0.529750
# America/Chicago 14  Not Windows  115.0      0.287500
#                 15      Windows  285.0      0.712500
# America/Denver  10  Not Windows  132.0      0.691099

# %%
sns.barplot(x='normed_total', y='tz', hue='os', data=results)
# Out:
# <Axes: xlabel='normed_total', ylabel='tz'>

# %%
g = count_subset.groupby('tz')
results2 = count_subset['total'] / g['total'].transform('sum')
results2.head()
# Out:
# 0    0.393939
# 1    0.606061
# 2    0.457143
# 3    0.542857
# 4    0.000000
# Name: total, dtype: float64

# %%
results['normed_total'] = results2.values
sns.barplot(x='normed_total', y='tz', hue='os', data=results)
# Out:
# <Axes: xlabel='normed_total', ylabel='tz'>
